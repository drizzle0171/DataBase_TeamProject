# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'NanumGothic'

# %%
#인천 vs 서울
#데이터 순서: 의료, 주거, 교통, 교육, 상권
incheon = np.array([0.071, 0.22, 0.056, 0.128, 0.312])
seoul = np.array([0.116, 0.038, 0.042, 0.132, 0.468])
X = np.arange(5)

plt.barh(X, incheon)
plt.barh(X, -seoul)
ticklabel = ['Medical', 'Housing', 'Traffic', 'Education', 'Commercial district']
plt.yticks(X, ticklabel)
plt.ylabel('Infrastructure')
plt.title('Seoul vs Incheon')
plt.show()
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
#인천 vs 서울
#데이터 순서: 고용율, 매매지수
incheon_rate = np.array([54.93, 84.53])
seoul_rate = np.array([55.93, 86.78])

Y = np.arange(2)
plt.barh(Y, incheon_rate)
plt.barh(Y, -seoul_rate)
ticklabel2 = ['Employment rate', 'Sales index']
plt.yticks(Y, ticklabel2)
plt.ylabel('Rate')
plt.title('Seoul vs Incheon')
plt.show()

# %%
#인천 vs 부산
#데이터 순서: 의료, 주거, 교통, 교육, 상권
incheon = np.array([0.071, 0.22, 0.056, 0.128, 0.312])
busan = np.array([0.086, 0.023, 0.022, 0.148, 0.493])
X = np.arange(5)

plt.barh(X, incheon)
plt.barh(X, -busan)
ticklabel = ['Medical', 'Housing', 'Traffic', 'Education', 'Commercial district']
plt.yticks(X, ticklabel)
plt.ylabel('Infrastructure')
plt.title('Busan vs Incheon')
plt.show()

# %%
#인천 vs 부산
#데이터 순서: 고용율, 매매지수
incheon_rate = np.array([54.93, 84.53])
busan_rate = np.array([51.43, 87.39])

Y = np.arange(2)
plt.barh(Y, incheon_rate)
plt.barh(Y, -busan_rate)
ticklabel2 = ['Employment rate', 'Sales index']
plt.yticks(Y, ticklabel2)
plt.ylabel('Rate')
plt.title('Busan vs Incheon')
plt.show()

# %%
#인천 vs 대전
#데이터 순서: 의료, 주거, 교통, 교육, 상권
incheon = np.array([0.071, 0.22, 0.056, 0.128, 0.312])
daejeon = np.array([0.086, 0.020, 0.021, 0.149, 0.596])
X = np.arange(5)

plt.barh(X, incheon)
plt.barh(X, -daejeon)
ticklabel = ['Medical', 'Housing', 'Traffic', 'Education', 'Commercial district']
plt.yticks(X, ticklabel)
plt.ylabel('Infrastructure')
plt.title('Daejeon vs Incheon')
plt.show()

# %%
#인천 vs 대전
#데이터 순서: 고용율, 매매지수
incheon_rate = np.array([54.93, 84.53])
daejeon_rate = np.array([57.03, 77.05])

Y = np.arange(2)
plt.barh(Y, incheon_rate)
plt.barh(Y, -daejeon_rate)
ticklabel2 = ['Employment rate', 'Sales index']
plt.yticks(Y, ticklabel2)
plt.ylabel('Rate')
plt.title('Daejeon vs Incheon')
plt.show()
