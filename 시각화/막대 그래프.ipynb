# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#의료
#인구 수 (인천 - 서울 - 부산 - 대전 순): 31459 50541 27150 27149
Medical = np.array([0.071, 0.116, 0.086, 0.086])
X = np.arange(4)

plt.bar(X, Medical)
ticklabel = ['Incheon', 'Seoul', 'Busan', 'Daejeon']
plt.xticks(X, ticklabel)
plt.title('MEDICAL')
plt.show()

# %%
#주거
#인구 수 (인천 - 서울 - 부산 - 대전 순): 31459 50541 27150 27149
Housing = np.array([0.022, 0.038, 0.023, 0.020])
X = np.arange(4)

plt.bar(X, Housing)
ticklabel = ['Incheon', 'Seoul', 'Busan', 'Daejeon']
plt.xticks(X, ticklabel)
plt.title('HOUSING')
plt.show()

# %%
#교통
#인구 수 (인천 - 서울 - 부산 - 대전 순): 31459 50541 27150 27149
Traffic = np.array([0.056, 0.042, 0.022, 0.021])
X = np.arange(4)

plt.bar(X, Traffic)
ticklabel = ['Incheon', 'Seoul', 'Busan', 'Daejeon']
plt.xticks(X, ticklabel)
plt.title('TRAFFIC')
plt.show()

# %%
#교육
#인구 수 (인천 - 서울 - 부산 - 대전 순): 31459 50541 27150 27149
Education = np.array([0.128, 0.132, 0.148, 0.149])
X = np.arange(4)

plt.bar(X, Education)
ticklabel = ['Incheon', 'Seoul', 'Busan', 'Daejeon']
plt.xticks(X, ticklabel)
plt.title('EDUCATION')
plt.show()

# %%
#상권
#인구 수 (인천 - 서울 - 부산 - 대전 순): 31459 50541 27150 27149
Commercial_district = np.array([0.312, 0.468, 0.493, 0.596])
X = np.arange(4)

plt.bar(X, Commercial_district)
ticklabel = ['Incheon', 'Seoul', 'Busan', 'Daejeon']
plt.xticks(X, ticklabel)
plt.title('COMMERCIAL DISTRICT')
plt.show()

# %%
#고용율
#인구 수 (인천 - 서울 - 부산 - 대전 순): 31459 50541 27150 27149
Employment_rate = np.array([54.93, 55.93, 51.43, 57.03])
X = np.arange(4)

plt.bar(X, Employment_rate)
ticklabel = ['Incheon', 'Seoul', 'Busan', 'Daejeon']
plt.xticks(X, ticklabel)
plt.title('EMPLOYMENT RATE')
plt.show()

# %%
#매매지수

Sales_index = np.array([84.53, 86.73, 87.39, 77.05])
X = np.arange(4)

plt.bar(X, Sales_index)
ticklabel = ['Incheon', 'Seoul', 'Busan', 'Daejeon']
plt.xticks(X, ticklabel)
plt.title('SALES INDEX')
plt.show()
